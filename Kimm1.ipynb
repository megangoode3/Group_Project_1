# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import json
import requests

# %%
#Api config
url = "https://api.fda.gov/drug/event.json?"
query = "ibuprofen"
Query_url = url+"&search="+query

print(Query_url)
# Out:
# https://api.fda.gov/drug/event.json?&search=ibuprofen

# %%
fda_response= requests.get(Query_url).json()

print(json.dumps(fda_response, indent=4, sort_keys=True))
# Out:
# {
#     "meta": {
#         "disclaimer": "Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.",
#         "last_updated": "2023-01-30",
#         "license": "https://open.fda.gov/license/",
#         "results": {
#             "limit": 1,
#             "skip": 0,
#             "total": 244757
#         },
#         "terms": "https://open.fda.gov/terms/"
#     },
#     "results": [
#         {
#             "companynumb": "US-JNJFOC-20130719067",
#             "duplicate": "1",
#             "fulfillexpeditecriteria": "2",
#             "patient": {
#                 "drug": [
#                     {
#                         "drugadditional": "3",
#                         "drugauthorizationnumb": "17463",
#                         "drugcharacterization": "1",
# ...

# %%
Alzheimer_file= "./Resources/Alzheimer_s_Disease_and_Healthy_Aging_Data.csv"
Alzheimer_file_df= pd.read_csv(Alzheimer_file)
Alzheimer_file_df.head()
# Out:
# c:\Users\Owner\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3186: DtypeWarning: Columns (17,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    RowId  YearStart  YearEnd LocationAbbr LocationDesc Datasource  \
# 0    NaN       2020     2020           HI       Hawaii      BRFSS
# 1    NaN       2017     2017           ID        Idaho      BRFSS
# 2    NaN       2017     2017           ID        Idaho      BRFSS
# 3    NaN       2018     2018           ID        Idaho      BRFSS
# 4    NaN       2020     2020           IN      Indiana      BRFSS
#
#             Class                                            Topic  \
# 0  Overall Health                     Arthritis among older adults
# 1   Mental Health                 Lifetime diagnosis of depression
# 2  Overall Health                     Arthritis among older adults
# ...

# %%
#National Library of Medicine API
url2="https://rxnav.nlm.nih.gov"
