# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import ast

base_url = "http://apps.who.int/gho/athena/api/GHO?label=DISEASECAUSE&filter=COUNTRY:USA&format=json"

# %%
# Read the data from the WHO API
response = requests.get(base_url).json()
# data = ast.literal_eval(json.dumps(response))

response
# Out:
# {'copyright': '(c) World Health Organization',
#  'dataset': [],
#  'attribute': [{'label': 'CATEGORY', 'display': 'Category'},
#   {'label': 'RENDERER_ID', 'display': 'Renderer ID'},
#   {'label': 'DEFINITION_XML', 'display': 'Definition (XML)'},
#   {'label': 'IMR_ID', 'display': 'IMR identifier'},
#   {'label': 'DISPLAY_FR', 'display': 'Français'},
#   {'label': 'DISPLAY_ES', 'display': 'Español'}],
#  'dimension': [{'label': 'GHO',
#    'display': 'Indicator',
#    'isMeasure': True,
#    'code': [{'label': 'MDG_0000000001',
#      'display': 'Infant mortality rate (between birth and 11 months per 1000 live births)',
#      'display_sequence': 30,
#      'url': 'https://www.who.int/data/gho/indicator-metadata-registry/imr-details/1',
#      'attr': [{'category': 'DEFINITION_XML',
#        'value': 'http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=1'},
# ...
