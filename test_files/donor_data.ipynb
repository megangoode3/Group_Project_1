# %%
# import depenedencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import hvplot.pandas
import requests
from api_keys import weather_api_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6608\2968779287.py in <module>
#       5 import hvplot.pandas
#       6 import requests
# ----> 7 from api_keys import weather_api_key
#
# ModuleNotFoundError: No module named 'api_keys'

# %%
# read in csv file
donor_df = pd.read_csv("Weekly_Provisional_Counts_of_Deaths_by_State_and_Select_Causes__2020-2023.csv")
donor_df.head()
# Out:
#    Data As Of Jurisdiction of Occurrence  MMWR Year  MMWR Week  \
# 0  02/01/2023              United States       2020          1
# 1  02/01/2023              United States       2020          2
# 2  02/01/2023              United States       2020          3
# 3  02/01/2023              United States       2020          4
# 4  02/01/2023              United States       2020          5
#
#   Week Ending Date  All Cause  Natural Cause  Septicemia (A40-A41)  \
# 0       2020-01-04      60193          55019                 843.0
# 1       2020-01-11      60735          55754                 861.0
# 2       2020-01-18      59362          54516                 829.0
# 3       2020-01-25      59162          54401                 828.0
# 4       2020-02-01      58844          54007                 811.0
#
#    Malignant neoplasms (C00-C97)  Diabetes mellitus (E10-E14)  ...  flag_alz  \
# 0                        11569.0                       1829.0  ...       NaN
# ...

# %%
# Narrow down the data to only the columns we need
deathcounts_df = donor_df[['Jurisdiction of Occurrence', 'MMWR Year', 'MMWR Week','Alzheimer disease (G30)']]
deathcounts_df.count()
# Out:
# Jurisdiction of Occurrence    8640
# MMWR Year                     8640
# MMWR Week                     8640
# Alzheimer disease (G30)       7218
# dtype: int64

# %%
# rename columns and fill in missing data with 0
deathcounts_df = deathcounts_df.rename(columns={'Jurisdiction of Occurrence': 'State', 'MMWR Year': 'Year', 'MMWR Week': 'Week', 'Alzheimer disease (G30)': 'Deaths'})
deathcounts_df = deathcounts_df.fillna(0)
deathcounts_df.head()
# Out:
#            State  Year  Week  Deaths
# 0  United States  2020     1  2537.0
# 1  United States  2020     2  2566.0
# 2  United States  2020     3  2491.0
# 3  United States  2020     4  2517.0
# 4  United States  2020     5  2480.0

# %%
# remove the rows with US as the state
deathcounts_df = deathcounts_df[deathcounts_df['State'] != 'United States']

# add latitudes and longitudes to the dataframe

# %%
# separate the data by year
df_2020 = deathcounts_df[deathcounts_df['Year'] == 2020]
df_2021 = deathcounts_df[deathcounts_df['Year'] == 2021]
df_2022 = deathcounts_df[deathcounts_df['Year'] == 2022]

# %%
# create a plot tracking the number of deaths over time for each state
plot_2020 = df_2020.hvplot.points(x='Week', y='Deaths', by='State', xlabel='Week', ylabel='Deaths', title='Deaths by Week in 2020', width=2000, height=1000)
plot_2020
# Out:
# :NdOverlay   [State]
#    :Points   [Week,Deaths]

# %%
plot_2021 = df_2021.hvplot.points(x='Week', y='Deaths', by='State', xlabel='Week', ylabel='Deaths', title='Deaths by Week in 2021', width=2000, height=1000)
plot_2021
# Out:
# :NdOverlay   [State]
#    :Points   [Week,Deaths]

# %%
plot_2022 = df_2022.hvplot.points(x='State', y='State', geo=True, width=2000, height=1000)
plot_2022
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\freak\anaconda3\envs\PythonData\lib\site-packages\IPython\core\formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# c:\Users\freak\anaconda3\envs\PythonData\lib\site-packages\holoviews\core\dimension.py in _repr_mimebundle_(self, include, exclude)
#    1288         combined and returned.
#    1289         """
# -> 1290         return Store.render(self)
#    1291
#    1292
#
# c:\Users\freak\anaconda3\envs\PythonData\lib\site-packages\holoviews\core\options.py in render(cls, obj)
#    1423         data, metadata = {}, {}
#    1424         for hook in hooks:
# -> 1425             ret = hook(obj)
#    1426             if ret is None:
# ...

# %%
# create a plot that shows the number of deaths by state
plot_2022
